# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel('water.xlsx')
df1
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
df1.groupby('UNION').count()
# Out:
#                      LAT_DEG  LONG_DEG  WELL_DEPTH  HCO3  Ca  Cl   F  Fe   K  \
# UNION
# Aliabad                    7         7           7     7   7   7   7   7   7
# Ambikapur                  3         3           3     3   3   3   3   3   3
# Char Madhabdia             4         4           4     4   4   4   4   4   4
# Decreer Char               4         4           4     4   4   4   4   4   4
# Faridpur Paurashava        8         8           8     8   8   8   8   8   8
# Greda                      3         3           3     3   3   3   3   3   3
# Ishan Gopalpur             4         4           4     4   4   4   4   4   4
# Kaijuri                   13        13          13    13  13  13  13  13  13
# Kanaipur                   5         5           5     5   5   5   5   5   5
# Krishnanagar               6         6           6     6   6   6   6   6   6
# Majchar                    5         5           5     5   5   5   5   5   5
# ...

# %%
df1.drop_duplicates('UNION' , inplace=True)

# %%
df1.groupby('UNION').count()
# Out:
#                      LAT_DEG  LONG_DEG  WELL_DEPTH  HCO3  Ca  Cl  F  Fe  K  \
# UNION
# Aliabad                    1         1           1     1   1   1  1   1  1
# Ambikapur                  1         1           1     1   1   1  1   1  1
# Char Madhabdia             1         1           1     1   1   1  1   1  1
# Decreer Char               1         1           1     1   1   1  1   1  1
# Faridpur Paurashava        1         1           1     1   1   1  1   1  1
# Greda                      1         1           1     1   1   1  1   1  1
# Ishan Gopalpur             1         1           1     1   1   1  1   1  1
# Kaijuri                    1         1           1     1   1   1  1   1  1
# Kanaipur                   1         1           1     1   1   1  1   1  1
# Krishnanagar               1         1           1     1   1   1  1   1  1
# Majchar                    1         1           1     1   1   1  1   1  1
# ...

# %%
df = pd.DataFrame(df1,columns=['HCO3','Ca','Cl','F','Fe','K','Mg','Na','NO3','pH','SO4','Mn','AsIII'])
df
# Out:
#     HCO3     Ca    Cl     F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  \
# 0    471  127.0  27.6  0.20   0.447  4.5  27.8   22.5  0.2  6.84  13.5  1.470
# 2    529  116.0  33.9  0.20   9.600  3.9  32.5   19.0  0.2  6.99   8.2  1.130
# 4    561   88.4  13.5  0.24   7.680  5.0  40.0   36.6  4.7  6.82   0.5  0.080
# 5    563   65.7   7.2  0.18  16.100  7.0  40.0   40.2  0.2  6.61   0.1  0.082
# 9    607  123.0   3.6  0.12   9.340  4.8  28.0   28.0  3.7  6.86   0.2  0.210
# 13   502   43.9  86.0  0.18   6.110  8.6  41.9  105.0  0.2  6.57   0.6  0.081
# 18   300   78.6  18.6  0.10   0.224  3.5  14.5   13.8  0.2  7.23  11.0  0.478
# 19   688  156.0   2.6  0.03   0.144  5.4  34.7   13.8  0.4  6.88   0.3  1.280
# 22   534   94.5   1.8  0.12   5.530  4.6  37.0   12.1  0.2  7.00   0.1  0.994
# 30   305   81.4  15.8  0.09   0.143  4.7  13.3    9.8  0.2  7.20   4.7  0.092
# 32   371   89.3   4.0  0.11   0.479  3.7  19.7    5.1  0.2  7.22   2.8  0.611
# ...

# %%
df.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
ds = pd.read_excel('xyz.xlsx')
ds
# Out:
#        NAME   AGE DEPARTMENT DATE_OF_JOIN DATE_OF_EXIT
# 0     kunal  23.0  marketing   2021-01-01   2022-05-09
# 1   shubham  21.0         it   2021-12-03   2022-08-08
# 2    vaibhu  33.0       arts   2021-09-03   2022-04-03
# 3     karan  25.0         ui   2021-06-03   2021-09-05
# 4      yash  26.0       arts   2022-07-04   2022-12-12
# 5    sanket  24.0         it   2022-09-22   2022-11-14
# 6    chirag  29.0       arts   2021-05-07   2021-08-09
# 7    mayank  34.0  marketing   2021-05-04   2021-07-08
# 8    nitesh  67.0         it   2022-05-18   2022-07-20
# 9     dhrvu  39.0  marketing   2022-02-23   2022-05-21
# 10    morya  18.0         it   2021-04-12   2021-04-27
# 11  shahhed  20.0       arts   2021-06-12   2021-09-19
# 12    amjad  40.0  marketing   2020-02-22   2022-05-11
# 13    bablu  46.0         it   2019-09-08   2020-09-09
