# %%
import pandas as pd
wather_data = {
    'day':['1/1/2022','1/2/2022','1/3/2022','1/4/2022','1/5/2022','1/6/2022'],
    'tempre':[19 ,17,24,35,22,26],
    'windspeed':[6,7,4,3,7,9],
    'event':['rain','sunny','snow','snow','rain' ,'sunny']
}
df = pd.DataFrame(wather_data)
df
# Out:
#         day  tempre  windspeed  event
# 0  1/1/2022      19          6   rain
# 1  1/2/2022      17          7  sunny
# 2  1/3/2022      24          4   snow
# 3  1/4/2022      35          3   snow
# 4  1/5/2022      22          7   rain
# 5  1/6/2022      26          9  sunny

# %%
row , columns = df.shape
row
# Out:
# 6

# %%
df.tail(2)
# Out:
#         day  tempre  windspeed  event
# 4  1/5/2022      22          7   rain
# 5  1/6/2022      26          9  sunny

# %%
df[1:6]
# Out:
#         day  tempre  windspeed  event
# 1  1/2/2022      17          7  sunny
# 2  1/3/2022      24          4   snow
# 3  1/4/2022      35          3   snow
# 4  1/5/2022      22          7   rain
# 5  1/6/2022      26          9  sunny

# %%
df.columns
# Out:
# Index(['day', 'tempre', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2022
# 1    1/2/2022
# 2    1/3/2022
# 3    1/4/2022
# 4    1/5/2022
# 5    1/6/2022
# Name: day, dtype: object

# %%
df.tempre
# Out:
# 0    19
# 1    17
# 2    24
# 3    35
# 4    22
# 5    26
# Name: tempre, dtype: int64

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['day' , 'event','tempre']]
# Out:
#         day  event  tempre
# 0  1/1/2022   rain      19
# 1  1/2/2022  sunny      17
# 2  1/3/2022   snow      24
# 3  1/4/2022   snow      35
# 4  1/5/2022   rain      22
# 5  1/6/2022  sunny      26

# %%
df['tempre'].max()
# Out:
# 35

# %%
# df['tempre'].mean()
df['tempre'].min()
df['tempre'].std()
# Out:
# 6.369196704975178

# %%
df.describe()
# Out:
#           tempre  windspeed
# count   6.000000    6.00000
# mean   23.833333    6.00000
# std     6.369197    2.19089
# min    17.000000    3.00000
# 25%    19.750000    4.50000
# 50%    23.000000    6.50000
# 75%    25.500000    7.00000
# max    35.000000    9.00000

# %%
df[['day','tempre']][df.tempre == df.tempre.max()]
# Out:
#         day  tempre
# 3  1/4/2022      35

# %%
df.set_index('day' , inplace=True)

# %%
df.loc['1/2/2022']
# Out:
# tempre          17
# windspeed        7
# event        sunny
# Name: 1/2/2022, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#         day  tempre  windspeed  event
# 0  1/1/2022      19          6   rain
# 1  1/2/2022      17          7  sunny
# 2  1/3/2022      24          4   snow
# 3  1/4/2022      35          3   snow
# 4  1/5/2022      22          7   rain
# 5  1/6/2022      26          9  sunny

# %%
df.set_index('event' , inplace=True)
df
# Out:
#             day  tempre  windspeed
# event
# rain   1/1/2022      19          6
# sunny  1/2/2022      17          7
# snow   1/3/2022      24          4
# snow   1/4/2022      35          3
# rain   1/5/2022      22          7
# sunny  1/6/2022      26          9

# %%
df.loc['snow']
# Out:
#             day  tempre  windspeed
# event
# snow   1/3/2022      24          4
# snow   1/4/2022      35          3

# %%
df.to_excel('wather.xlsx')

# %%
df1 = pd.read_excel('D:\shubham\python\Water.xlsx')

# %%
df1
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
 row , columns = df1.shape
row,columns
# Out:
# (64, 17)

# %%
df1[['UNION' ,'LAT_DEG']]
# Out:
#                   UNION  LAT_DEG
# 0   Faridpur Paurashava  23.6147
# 1   Faridpur Paurashava  23.6075
# 2             Ambikapur  23.6031
# 3   Faridpur Paurashava  23.6064
# 4               Aliabad  23.5689
# ..                  ...      ...
# 59              Kaijuri  23.5789
# 60              Majchar  23.6339
# 61  Faridpur Paurashava  23.5897
# 62  Faridpur Paurashava  23.6033
# 63              Aliabad  23.5919
#
# [64 rows x 2 columns]

# %%
df1.columns
# Out:
# Index(['LAT_DEG', 'LONG_DEG', 'UNION', 'WELL_DEPTH', 'HCO3', 'Ca', 'Cl', 'F',
#        'Fe', 'K', 'Mg', 'Na', 'NO3', 'pH', 'SO4', 'Mn', 'AsIII'],
#       dtype='object')

# %%
df1[1:7]
# Out:
#    LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 1  23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2  23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3  23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4  23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# 5  23.5792   89.8014              Kaijuri        54.3   563   65.7   7.2
# 6  23.5622   89.7992              Kaijuri        65.5   590  104.0   3.4
#
#       F      Fe    K    Mg    Na  NO3    pH  SO4     Mn  AsIII
# 1  0.40   4.240  3.9  29.6  25.0  0.2  7.17  0.2  1.130    990
# 2  0.20   9.600  3.9  32.5  19.0  0.2  6.99  8.2  1.130     27
# 3  0.10   0.944  6.2  30.6  30.9  0.2  6.82  3.9  0.999      4
# 4  0.24   7.680  5.0  40.0  36.6  4.7  6.82  0.5  0.080      4
# 5  0.18  16.100  7.0  40.0  40.2  0.2  6.61  0.1  0.082     39
# 6  0.12  11.300  4.1  38.6  24.7  0.2  6.77  0.1  0.103      4

# %%
df1.loc[:,['UNION','HCO3','LONG_DEG']]
# Out:
#                   UNION  HCO3  LONG_DEG
# 0   Faridpur Paurashava   471   89.8553
# 1   Faridpur Paurashava   580   89.8633
# 2             Ambikapur   529   89.8272
# 3   Faridpur Paurashava   568   89.8444
# 4               Aliabad   561   89.8536
# ..                  ...   ...       ...
# 59              Kaijuri   485   89.8411
# 60              Majchar   485   89.7581
# 61  Faridpur Paurashava   536   89.8128
# 62  Faridpur Paurashava   668   89.8408
# 63              Aliabad   432   89.8417
#
# [64 rows x 3 columns]

# %%
df1.loc[df1['HCO3'] > 800, 'HCO3']
# Out:
# 7     848
# 55    841
# Name: HCO3, dtype: int64

# %%
df1.loc[7]
# Out:
# LAT_DEG       23.5553
# LONG_DEG      89.8125
# UNION         Kaijuri
# WELL_DEPTH       53.3
# HCO3              848
# Ca               98.9
# Cl              127.0
# F                 0.1
# Fe               18.7
# K                 6.6
# Mg               40.6
# Na              175.0
# NO3               0.2
# pH               6.61
# SO4               0.8
# Mn              0.183
# AsIII               4
# Name: 7, dtype: object

# %%
df1.loc[df1.UNION == 'Kaijuri']
# Out:
#     LAT_DEG  LONG_DEG    UNION  WELL_DEPTH  HCO3     Ca     Cl     F     Fe  \
# 5   23.5792   89.8014  Kaijuri        54.3   563   65.7    7.2  0.18  16.10
# 6   23.5622   89.7992  Kaijuri        65.5   590  104.0    3.4  0.12  11.30
# 7   23.5553   89.8125  Kaijuri        53.3   848   98.9  127.0  0.10  18.70
# 8   23.5092   89.8197  Kaijuri        49.7   563  115.0   16.2  0.10   6.76
# 12  23.5158   89.8397  Kaijuri        53.3   614   57.1   56.7  0.19   4.84
# 26  23.5825   89.8403  Kaijuri       164.6   607   77.3   79.8  0.15   8.47
# 27  23.5825   89.8403  Kaijuri       137.2   610   67.2   93.0  0.14   1.73
# 40  23.5414   89.8044  Kaijuri        87.8   556   99.4    3.8  0.14   6.99
# 41  23.5397   89.8381  Kaijuri        54.3   541   64.3   36.6  0.20   4.96
# 42  23.5703   89.8411  Kaijuri        57.3   488   51.9   11.3  0.13  19.60
# 57  23.5767   89.8156  Kaijuri        27.4   700   87.1   67.8  0.20  10.40
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LAT_DEG     64 non-null     float64
#  1   LONG_DEG    64 non-null     float64
#  2   UNION       64 non-null     object
#  3   WELL_DEPTH  64 non-null     float64
#  4   HCO3        64 non-null     int64
#  5   Ca          64 non-null     float64
#  6   Cl          64 non-null     float64
#  7   F           64 non-null     float64
#  8   Fe          64 non-null     float64
#  9   K           64 non-null     float64
#  10  Mg          64 non-null     float64
#  11  Na          64 non-null     float64
#  12  NO3         64 non-null     float64
#  13  pH          64 non-null     float64
#  14  SO4         64 non-null     float64
#  15  Mn          64 non-null     float64
#  16  AsIII       64 non-null     int64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 8.6+ KB

# %%
df1.HCO3.dtype
# Out:
# dtype('int64')

# %%
df1.UNION.unique
# Out:
# <bound method Series.unique of 0     Faridpur Paurashava
# 1     Faridpur Paurashava
# 2               Ambikapur
# 3     Faridpur Paurashava
# 4                 Aliabad
#              ...
# 59                Kaijuri
# 60                Majchar
# 61    Faridpur Paurashava
# 62    Faridpur Paurashava
# 63                Aliabad
# Name: UNION, Length: 64, dtype: object>

# %%
df1.UNION.unique().shape[0]
# Out:
# 12

# %%
df1.rename(columns= {'UNION':'union'},inplace=True)

# %%
df1
# Out:
#     LAT_DEG  LONG_DEG                union  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
df1.union.max()
# Out:
# 'Uttar Channel'

# %%
df1.LONG_DEG.min()
# Out:
# 89.6975

# %%
df1.LONG_DEG.mean()
# Out:
# 89.815015625

# %%
df1.LONG_DEG.agg(['max' ,'mean', 'min'])
# Out:
# max     89.902500
# mean    89.815016
# min     89.697500
# Name: LONG_DEG, dtype: float64

# %%
gk =  df1.groupby('union')
gk.first()
# Out:
#                      LAT_DEG  LONG_DEG  WELL_DEPTH  HCO3     Ca    Cl     F  \
# union
# Aliabad              23.5689   89.8536        45.7   561   88.4  13.5  0.24
# Ambikapur            23.6031   89.8272        36.6   529  116.0  33.9  0.20
# Char Madhabdia       23.6869   89.7972        24.4   300   78.6  18.6  0.10
# Decreer Char         23.6058   89.8828        22.3   675  161.0  11.0  0.04
# Faridpur Paurashava  23.6147   89.8553        24.4   471  127.0  27.6  0.20
# Greda                23.5311   89.8531        50.3   502   43.9  86.0  0.18
# Ishan Gopalpur       23.6700   89.7253        29.0   534   94.5   1.8  0.12
# Kaijuri              23.5792   89.8014        54.3   563   65.7   7.2  0.18
# Kanaipur             23.5094   89.8103        25.9   607  123.0   3.6  0.12
# Krishnanagar         23.5794   89.7678        28.3   371   89.3   4.0  0.11
# Majchar              23.6372   89.7383        14.0   305   81.4  15.8  0.09
# ...

# %%
gk.get_group('Greda')
# Out:
#     LAT_DEG  LONG_DEG  union  WELL_DEPTH  HCO3    Ca    Cl     F    Fe    K  \
# 13  23.5311   89.8531  Greda        50.3   502  43.9  86.0  0.18  6.11  8.6
# 14  23.5347   89.8675  Greda        32.0   410  49.2   2.0  0.09  3.37  6.1
# 43  23.5567   89.8686  Greda        45.7   556  56.4  16.4  0.20  7.68  6.8
#
#       Mg     Na  NO3    pH  SO4     Mn  AsIII
# 13  41.9  105.0  0.2  6.57  0.6  0.081     46
# 14  37.0   14.0  0.2  7.04  0.1  0.041     40
# 43  32.0   65.7  0.2  6.57  0.5  0.111     18

# %%
df1
# Out:
#     LAT_DEG  LONG_DEG                union  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
df1.union.replace('Aliabad','shubham' ,inplace=True)

# %%
df1
# Out:
#     LAT_DEG  LONG_DEG                union  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              shubham        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              shubham        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
gk = df1.groupby('union')
gk.get_group('shubham')
# Out:
#     LAT_DEG  LONG_DEG    union  WELL_DEPTH  HCO3     Ca    Cl     F     Fe  \
# 4   23.5689   89.8536  shubham        45.7   561   88.4  13.5  0.24   7.68
# 15  23.5747   89.8825  shubham        40.5   566   95.7   7.6  0.11   8.83
# 16  23.5586   89.9025  shubham        41.1   714  167.0   5.5  0.14   1.10
# 17  23.5969   89.8769  shubham        20.1   553  129.0   3.8  0.10   2.21
# 44  23.5783   89.8942  shubham        48.8   773  138.0  17.7  0.08  10.10
# 56  23.5842   89.8611  shubham        49.7   249   34.8   4.0  0.16   3.37
# 63  23.5919   89.8417  shubham        50.0   432   54.6   4.8  0.16   6.27
#
#       K    Mg    Na  NO3    pH  SO4     Mn  AsIII
# 4   5.0  40.0  36.6  4.7  6.82  0.5  0.080      4
# 15  5.1  39.6  25.0  0.2  6.99  0.1  0.127    200
# 16  4.4  34.3  16.4  0.2  7.10  0.5  0.700      4
# 17  3.9  25.9   9.6  0.2  7.03  0.4  1.260     17
# 44  6.8  59.5  21.8  4.9  6.79  0.1  0.121      4
# 56  3.8  17.2  21.7  0.2  7.09  0.1  0.149     92
# ...

# %%
df1.groupby('union').count()
# Out:
#                      LAT_DEG  LONG_DEG  WELL_DEPTH  HCO3  Ca  Cl   F  Fe   K  \
# union
# Ambikapur                  3         3           3     3   3   3   3   3   3
# Char Madhabdia             4         4           4     4   4   4   4   4   4
# Decreer Char               4         4           4     4   4   4   4   4   4
# Faridpur Paurashava        8         8           8     8   8   8   8   8   8
# Greda                      3         3           3     3   3   3   3   3   3
# Ishan Gopalpur             4         4           4     4   4   4   4   4   4
# Kaijuri                   13        13          13    13  13  13  13  13  13
# Kanaipur                   5         5           5     5   5   5   5   5   5
# Krishnanagar               6         6           6     6   6   6   6   6   6
# Majchar                    5         5           5     5   5   5   5   5   5
# Uttar Channel              2         2           2     2   2   2   2   2   2
# ...

# %%
df1.union.apply(len)
# Out:
# 0     19
# 1     19
# 2      9
# 3     19
# 4      7
#       ..
# 59     7
# 60     7
# 61    19
# 62    19
# 63     7
# Name: union, Length: 64, dtype: int64

# %%
df1.fillna(df1.mean())
# Out:
# C:\Users\prati\AppData\Local\Temp\ipykernel_3568\4288736220.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.fillna(df1.mean())
#     LAT_DEG  LONG_DEG                union  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              shubham        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# ...

# %%
df1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# Length: 64, dtype: bool

# %%
#  dg = pd.concat(df1 , df) this will use for join two table

# %%
df1.drop_duplicates(inplace=True)
df1
# Out:
#     LAT_DEG  LONG_DEG                union  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              shubham        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              shubham        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
# ndf = pd.merge(df1 ,df2, on='union' , how='inner') for marge two data

# %%
gh = df1.groupby("union")
gh

# %%
for u ,u_df in gh:
    print(u)
    print(u_df)
# Out:
# Ambikapur
#     LAT_DEG  LONG_DEG      union  WELL_DEPTH  HCO3     Ca    Cl     F     Fe  \
# 2   23.6031   89.8272  Ambikapur        36.6   529  116.0  33.9  0.20  9.600
# 21  23.6292   89.8278  Ambikapur        32.0   402  101.0  16.0  0.06  0.827
# 37  23.5972   89.7900  Ambikapur        20.1   380   89.2   8.7  0.09  0.483
#
#       K    Mg    Na  NO3    pH   SO4     Mn  AsIII
# 2   3.9  32.5  19.0  0.2  6.99   8.2  1.130     27
# 21  4.4  18.8  11.2  0.2  7.01  10.8  0.919      4
# 37  3.1  22.3   7.4  0.2  7.00   0.6  0.983     17
# Char Madhabdia
#     LAT_DEG  LONG_DEG           union  WELL_DEPTH  HCO3     Ca    Cl     F  \
# 18  23.6869   89.7972  Char Madhabdia        24.4   300   78.6  18.6  0.10
# 20  23.6714   89.8083  Char Madhabdia        18.3   566  150.0  51.9  0.04
# 48  23.6669   89.8369  Char Madhabdia        21.9   444  115.0  13.8  0.06
# 49  23.6517   89.8169  Char Madhabdia        26.8   483  117.0  10.5  0.08
#
# ...

# %%
gh.get_group('shubham')
# Out:
#     LAT_DEG  LONG_DEG    union  WELL_DEPTH  HCO3     Ca    Cl     F     Fe  \
# 4   23.5689   89.8536  shubham        45.7   561   88.4  13.5  0.24   7.68
# 15  23.5747   89.8825  shubham        40.5   566   95.7   7.6  0.11   8.83
# 16  23.5586   89.9025  shubham        41.1   714  167.0   5.5  0.14   1.10
# 17  23.5969   89.8769  shubham        20.1   553  129.0   3.8  0.10   2.21
# 44  23.5783   89.8942  shubham        48.8   773  138.0  17.7  0.08  10.10
# 56  23.5842   89.8611  shubham        49.7   249   34.8   4.0  0.16   3.37
# 63  23.5919   89.8417  shubham        50.0   432   54.6   4.8  0.16   6.27
#
#       K    Mg    Na  NO3    pH  SO4     Mn  AsIII
# 4   5.0  40.0  36.6  4.7  6.82  0.5  0.080      4
# 15  5.1  39.6  25.0  0.2  6.99  0.1  0.127    200
# 16  4.4  34.3  16.4  0.2  7.10  0.5  0.700      4
# 17  3.9  25.9   9.6  0.2  7.03  0.4  1.260     17
# 44  6.8  59.5  21.8  4.9  6.79  0.1  0.121      4
# 56  3.8  17.2  21.7  0.2  7.09  0.1  0.149     92
# ...

# %%
gh.max()
# Out:
#                      LAT_DEG  LONG_DEG  WELL_DEPTH  HCO3     Ca     Cl     F  \
# union
# Ambikapur            23.6292   89.8278        36.6   529  116.0   33.9  0.20
# Char Madhabdia       23.6869   89.8369        26.8   566  150.0   51.9  0.10
# Decreer Char         23.6406   89.8878        26.8   841  190.0   11.3  0.08
# Faridpur Paurashava  23.6147   89.8633       213.4   668  142.0  195.0  0.40
# Greda                23.5567   89.8686        50.3   556   56.4   86.0  0.20
# Ishan Gopalpur       23.6761   89.7847        38.7   580  125.0   11.5  0.12
# Kaijuri              23.5825   89.8411       164.6   848  115.0  127.0  0.20
# Kanaipur             23.5436   89.8103        46.3   607  123.0   10.4  0.14
# Krishnanagar         23.5853   89.7678        30.5   668  124.0   14.7  0.13
# Majchar              23.6372   89.7936        35.1   622  180.0   87.0  0.13
# Uttar Channel        23.6964   89.8750        22.3   775  188.0    9.6  0.04
# ...

# %%
gh.describe()
# Out:
#                     LAT_DEG                                           \
#                       count       mean       std      min        25%
# union
# Ambikapur               3.0  23.609833  0.017029  23.5972  23.600150
# Char Madhabdia          4.0  23.669225  0.014488  23.6517  23.663100
# Decreer Char            4.0  23.625000  0.014640  23.6058  23.618925
# Faridpur Paurashava     8.0  23.599675  0.010413  23.5872  23.589075
# Greda                   3.0  23.540833  0.013858  23.5311  23.532900
# Ishan Gopalpur          4.0  23.662500  0.014181  23.6436  23.656125
# Kaijuri                13.0  23.559662  0.025692  23.5092  23.541400
# Kanaipur                5.0  23.521660  0.019064  23.4958  23.509400
# Krishnanagar            6.0  23.569117  0.015610  23.5411  23.565350
# Majchar                 5.0  23.621720  0.012708  23.6117  23.611900
# Uttar Channel           2.0  23.670150  0.037123  23.6439  23.657025
# ...
